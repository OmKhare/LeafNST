# %%
# import os
# import glob

# def rename_files(folder_path):
#     # Get a list of all image files in the folder
#     for folder in os.listdir(folder_path):
#         # print(folder_path)
#         folder_path1 = os.path.join(folder_path, folder)
#         image_files = glob.glob(os.path.join(folder_path1, '*.jpg'))
#         print(image_files)
#         exit()
#         # Sort the list of files
#         image_files.sort()
#         # Iterate over the sorted list and rename files sequentially
#         for i, file_path in enumerate(image_files):
#             # Extract the file extension
#             _, extension = os.path.splitext(file_path)
#             # Construct the new file name
#             new_file_name = f'img{i+1}{extension}'
#             # Rename the file and place it back in the same folder
#             os.rename(file_path, os.path.join(folder_path1, new_file_name))

# def rename_all_folders(root_folder):
#     # Iterate over each folder in the root folder
#     for folder_name in os.listdir(root_folder):
#         folder_path = os.path.join(root_folder, folder_name)
        
#         # Check if the item is a folder
#         if folder_path == os.path.isdir(folder_path):
#             print(folder_path)
#             # rename_files(folder_path)

# # Specify the root folder containing the folders with images
# root_folder = '../data/plantvillage-dataset'
# rename_all_folders(root_folder)
# Out:
# ../data/plantvillage-dataset/grayscale
# ../data/plantvillage-dataset/segmented
# ../data/plantvillage-dataset/color
# ../data/plantvillage-dataset/individual

# %%
#The above code does not work. 
#After doing this, we are not able to have a correspondance with the segmentation and the original image.

# %%
#This will provide number of images in the color folder of dataset which have its segmented images in the segmented folder.
import os
import glob
root_folder = '../data/plantvillage-dataset'
for folder_name in os.listdir(root_folder):
    folder_path = os.path.join(root_folder, folder_name)
    if folder_path == '../data/plantvillage-dataset/.DS_Store':
        continue
    if os.path.isdir(folder_path):
        if folder_path == '../data/plantvillage-dataset/segmented':
            for folder in os.listdir(folder_path):
                folder_path1 = os.path.join(folder_path, folder)
                # image_files_JPG = glob.glob(os.path.join(folder_path1, '*.JPG'))
                image_files_jpg = glob.glob(os.path.join(folder_path1, '*.jpg'))
        if folder_path == '../data/plantvillage-dataset/color':
            for folder in os.listdir(folder_path):
                folder_path1 = os.path.join(folder_path, folder)
                image_files_JPG = glob.glob(os.path.join(folder_path1, '*.JPG'))
                # image_files_jpg = glob.glob(os.path.join(folder_path1, '*.jpg'))
print(image_files_JPG)
print(image_files_jpg)
# Out:
# ['../data/plantvillage-dataset/color/Apple___healthy/d5551b0d-594f-48c7-b689-c409145bf6cf___RS_HL 6325.JPG', '../data/plantvillage-dataset/color/Apple___healthy/c69a5e33-20a9-4f74-922e-c3bc34b1c98e___RS_HL 7921.JPG', '../data/plantvillage-dataset/color/Apple___healthy/a5da624b-8a38-4e64-ae7f-ace8b7c20548___RS_HL 5997.JPG', '../data/plantvillage-dataset/color/Apple___healthy/e99a7776-9700-4845-bec6-b3db896f5562___RS_HL 7732.JPG', '../data/plantvillage-dataset/color/Apple___healthy/d40c491e-7efa-4e8e-865a-fc2e5a240a66___RS_HL 8148.JPG', '../data/plantvillage-dataset/color/Apple___healthy/e8f01d04-432d-4894-990b-df471a782651___RS_HL 6297.JPG', '../data/plantvillage-dataset/color/Apple___healthy/a0670cfe-00e2-4c7a-a9f7-29408debdc3a___RS_HL 6061.JPG', '../data/plantvillage-dataset/color/Apple___healthy/f591e5cc-e9fc-4d82-b2cd-09ab19cb4581___RS_HL 7829.JPG', '../data/plantvillage-dataset/color/Apple___healthy/a0a31340-6426-4e4b-9473-4daacbc305dc___RS_HL 7644.JPG', '../data/plantvillage-dat
# ...
